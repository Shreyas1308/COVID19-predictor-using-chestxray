# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.2.4-cp38-cp38-win_amd64.whl (9.3 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\shreyas\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\shreyas\appdata\local\programs\python\python38\lib\site-packages (from pandas) (1.20.2)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: six>=1.5 in c:\users\shreyas\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.2.4 pytz-2021.1

# %%
import pandas as pd
import os
import shutil

# %%
#for positive set
FILE_PATH = ""
IMAGE_PATH = ""

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (950, 30)

# %%
df.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 2        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 3        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 4  Changhua Christian Hospital, Changhua City, Ta...  images
#
#                                             filename                   doi  \
# 0  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 1  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 2  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 3  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...  10.1056/nejmc2001272
# 4                              nejmc2001573_f1a.jpeg  10.1056/NEJMc2001573
#
#                                                  url  license  \
# 0  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 1  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 2  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 3  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
# 4  https://www.nejm.org/doi/full/10.1056/NEJMc200...      NaN
#
#                                       clinical_notes other_notes Unnamed: 29
# 0  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 1  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 2  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 3  On January 22, 2020, a 65-year-old man with a ...         NaN         NaN
# 4   diffuse infiltrates in the bilateral lower lungs         NaN         NaN
#
# [5 rows x 30 columns]

# %%
TARGET_DIR = "Dataset/Covid"
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)
    print("Covid folder created")
# Out:
# Covid folder created

# %%
cnt = 0
for (i,row) in df.iterrows():
    if row["finding"] == "Pneumonia/Viral/COVID-19" and row["view"] == "PA":
        filename = row["filename"]
        image_path = os.path.join(IMAGE_PATH,filename)
        image_path_copy = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path, image_path_copy)
        print("Moving Image",cnt)
        cnt += 1
print(cnt)
# Out:
# Moving Image 0
# Moving Image 1
# Moving Image 2
# Moving Image 3
# Moving Image 4
# Moving Image 5
# Moving Image 6
# Moving Image 7
# Moving Image 8
# Moving Image 9
# Moving Image 10
# Moving Image 11
# Moving Image 12
# Moving Image 13
# Moving Image 14
# Moving Image 15
# Moving Image 16
# Moving Image 17
# Moving Image 18
# Moving Image 19
# Moving Image 20
# Moving Image 21
# Moving Image 22
# Moving Image 23
# Moving Image 24
# Moving Image 25
# Moving Image 26
# Moving Image 27
# Moving Image 28
# Moving Image 29
# Moving Image 30
# Moving Image 31
# Moving Image 32
# Moving Image 33
# Moving Image 34
# Moving Image 35
# Moving Image 36
# Moving Image 37
# Moving Image 38
# Moving Image 39
# Moving Image 40
# Moving Image 41
# Moving Image 42
# Moving Image 43
# Moving Image 44
# Moving Image 45
# Moving Image 46
# Moving Image 47
# Moving Image 48
# Moving Image 49
# Moving Image 50
# Moving Image 51
# Moving Image 52
# Moving Image 53
# Moving Image 54
# Moving Image 55
# Moving Image 56
# Moving Image 57
# Moving Image 58
# Moving Image 59
# Moving Image 60
# Moving Image 61
# Moving Image 62
# Moving Image 63
# Moving Image 64
# Moving Image 65
# Moving Image 66
# Moving Image 67
# Moving Image 68
# Moving Image 69
# Moving Image 70
# Moving Image 71
# Moving Image 72
# Moving Image 73
# Moving Image 74
# Moving Image 75
# Moving Image 76
# Moving Image 77
# Moving Image 78
# Moving Image 79
# Moving Image 80
# Moving Image 81
# Moving Image 82
# Moving Image 83
# Moving Image 84
# Moving Image 85
# Moving Image 86
# Moving Image 87
# Moving Image 88
# Moving Image 89
# Moving Image 90
# Moving Image 91
# Moving Image 92
# Moving Image 93
# Moving Image 94
# Moving Image 95
# Moving Image 96
# Moving Image 97
# Moving Image 98
# Moving Image 99
# Moving Image 100
# Moving Image 101
# Moving Image 102
# Moving Image 103
# Moving Image 104
# Moving Image 105
# Moving Image 106
# Moving Image 107
# Moving Image 108
# Moving Image 109
# Moving Image 110
# Moving Image 111
# Moving Image 112
# Moving Image 113
# Moving Image 114
# Moving Image 115
# Moving Image 116
# Moving Image 117
# Moving Image 118
# Moving Image 119
# Moving Image 120
# Moving Image 121
# Moving Image 122
# Moving Image 123
# Moving Image 124
# Moving Image 125
# Moving Image 126
# Moving Image 127
# Moving Image 128
# Moving Image 129
# Moving Image 130
# Moving Image 131
# Moving Image 132
# Moving Image 133
# Moving Image 134
# Moving Image 135
# Moving Image 136
# Moving Image 137
# Moving Image 138
# Moving Image 139
# Moving Image 140
# Moving Image 141
# Moving Image 142
# Moving Image 143
# Moving Image 144
# Moving Image 145
# Moving Image 146
# Moving Image 147
# Moving Image 148
# Moving Image 149
# Moving Image 150
# Moving Image 151
# Moving Image 152
# Moving Image 153
# Moving Image 154
# Moving Image 155
# Moving Image 156
# Moving Image 157
# Moving Image 158
# Moving Image 159
# Moving Image 160
# Moving Image 161
# Moving Image 162
# Moving Image 163
# Moving Image 164
# Moving Image 165
# Moving Image 166
# Moving Image 167
# Moving Image 168
# Moving Image 169
# Moving Image 170
# Moving Image 171
# Moving Image 172
# Moving Image 173
# Moving Image 174
# Moving Image 175
# Moving Image 176
# Moving Image 177
# Moving Image 178
# Moving Image 179
# Moving Image 180
# Moving Image 181
# Moving Image 182
# Moving Image 183
# Moving Image 184
# Moving Image 185
# Moving Image 186
# Moving Image 187
# Moving Image 188
# Moving Image 189
# Moving Image 190
# Moving Image 191
# Moving Image 192
# Moving Image 193
# Moving Image 194
# Moving Image 195
# 196

# %%
#for negative sets
import random
KAGGLE_FILE_PATH = 
KAGGLE_NORMAL_DIR = ""

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)

# %%
random.shuffles(images_names)

# %%
for i in range(142):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_FILE_PATH,image_name)
    target_path = os.path.join(KAGGLE_NORMAL_DIR,image_name)
    shutil.copy2(image_path, target_path)
    print("Moving Image", i)
